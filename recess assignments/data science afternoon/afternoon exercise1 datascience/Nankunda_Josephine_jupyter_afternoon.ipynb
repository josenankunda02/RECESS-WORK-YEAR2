# %%
#DATASET ONE

# %%
import pandas as pd

# %%
data =pd.read_csv("mine.csv")
data
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
# head()  displays the first few rows of the DataFrame:
data.head()
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %%
# tail()  displays the last few rows of the DataFrame:
data.tail()
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4

# %%
# info()  gets information about the DataFrame, including the column names, data types, and non-null counts
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 5.4 KB

# %%
# dropna()  removes rows or columns with missing values
data.dropna()
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [164 rows x 4 columns]

# %%
# fillna()  fills missing values in the DataFrame
data.fillna(4)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
#DATASET TWO

# %%
df=pd.read_csv("work.csv")
df
# Out:
#      Name         city    age py-score
# 0    Emma      Kampala     23       90
# 1  Wilber        Mbale     26       75
# 2   Robin         Gulu     25     mine
# 3   Tevor  Livingstone    NaN       89
# 4    Yeko       Tororo     20       94
# 5  Miriam         Arua  Train      NaN
# 6   Jesca      Mbarara     21       84

# %%
#Wrong data: 
# Use the fillna()

# %%
df.fillna()
# Out:
#      Name         city   age py-score
# 0    Emma      Kampala  23.0       90
# 1  Wilber        Mbale  26.0       75
# 2   Robin         Gulu  25.0     mine
# 3   Tevor  Livingstone  23.0       89
# 4    Yeko       Tororo  20.0       94
# 5  Miriam         Arua  23.0       20
# 6   Jesca      Mbarara  21.0       84

# %%
# Correlatin matrix
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
#Wrong format
df.fillna(80)
# Out:
#      Name         city   age  py-score
# 0    Emma      Kampala  23.0      90.0
# 1  Wilber        Mbale  26.0      75.0
# 2   Robin         Gulu  25.0      80.0
# 3   Tevor  Livingstone  23.0      89.0
# 4    Yeko       Tororo  20.0      94.0
# 5  Miriam         Arua  23.0      80.0
# 6   Jesca      Mbarara  21.0      84.0

# %%
#Duplicated 
duplicate_rows = df.duplicated()
print("Number of duplicate rows:", duplicate_rows.sum())
# Out:
# Number of duplicate rows: 0
