# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
#control display of seaborn data
pd.options.display.max_columns=50
sns.set(style="darkgrid",rc={"axes.facecolor":'#FFFFFF'})

# %%
data = pd.read_csv('bse_dataset4.csv')
data
# Out:
#                Timestamp         gender   Age               emotion  \
# 0    05/07/2023 09:38:39           Male  21.0               Content
# 1    05/07/2023 09:38:57  Marabou stock  45.0                 Weird
# 2    05/07/2023 09:39:09        Female   20.0                 Happy
# 3    05/07/2023 09:39:12           Male  21.0                 Happy
# 4    05/07/2023 09:39:14         Female  21.0                 Happy
# 5                    NaN         Female  23.0                Happy
# 6    05/07/2023 09:39:21         female  21.0            irritated
# 7    05/07/2023 09:39:23        Female   22.0  In a state of wonder
# 8    05/07/2023 09:39:26           Male  22.0                   Sad
# 9    05/07/2023 09:39:27         Female  20.0                 happy
# 10            2023/12/26           Male  24.0                 Happy
# 11   05/07/2023 09:39:27         Female  20.0                 happy
# 12   05/07/2023 09:39:38           Male  25.0                 Happy
# ...

# %%
# Number of rows and columns 
data.shape
# Out:
# (169, 15)

# %%
# Columns present
data.columns
# Out:
# Index(['Timestamp', 'gender', 'Age', 'emotion', 'YOB', 'CGPA',
#        'Do you have a Girl Friend or BOY Friend', 'Do you have Depression?',
#        'Do you have Anxiety?', 'Do you have Panic attack?',
#        'Did you have seek any specialist for a treatment? ', 'Duration',
#        'Pulse', 'Maxpulse', 'Calories'],
#       dtype='object')

# %%
data2 =data.dropna()
data2
# Out:
#                Timestamp         gender   Age  emotion   YOB     CGPA  \
# 0    05/07/2023 09:38:39           Male  21.0  Content  2002     4.22
# 1    05/07/2023 09:38:57  Marabou stock  45.0    Weird  2100      8.9
# 2    05/07/2023 09:39:09        Female   20.0    Happy  2002     3.98
# 3    05/07/2023 09:39:12           Male  21.0    Happy  2003     4.37
# 4    05/07/2023 09:39:14         Female  21.0    Happy  2002     3.63
# ..                   ...            ...   ...      ...   ...      ...
# 164  05/07/2023 09:44:09           Male  22.0   Angry   1999      3.5
# 165  05/07/2023 09:44:14           male  23.0      sad  1999        4
# 166  05/07/2023 09:44:15           male  20.0     calm  2002      3.7
# 167  05/07/2023 09:44:35         Female  21.0      sad  2001      3.8
# 168  05/07/2023 09:45:13         Female  20.0    Happy  2022  4......
#
#     Do you have a Girl Friend or BOY Friend Do you have Depression?  \
# ...

# %%
# Remove all null values from dataset
data =data.dropna(inplace=True)
data

# %%
# Fill all empty cells with a value
data.fillna(100)
# Out:
#                Timestamp         gender   Age  emotion   YOB     CGPA  \
# 0    05/07/2023 09:38:39           Male  21.0  Content  2002     4.22
# 1    05/07/2023 09:38:57  Marabou stock  45.0    Weird  2100      8.9
# 2    05/07/2023 09:39:09        Female   20.0    Happy  2002     3.98
# 3    05/07/2023 09:39:12           Male  21.0    Happy  2003     4.37
# 4    05/07/2023 09:39:14         Female  21.0    Happy  2002     3.63
# ..                   ...            ...   ...      ...   ...      ...
# 164  05/07/2023 09:44:09           Male  22.0   Angry   1999      3.5
# 165  05/07/2023 09:44:14           male  23.0      sad  1999        4
# 166  05/07/2023 09:44:15           male  20.0     calm  2002      3.7
# 167  05/07/2023 09:44:35         Female  21.0      sad  2001      3.8
# 168  05/07/2023 09:45:13         Female  20.0    Happy  2022  4......
#
#     Do you have a Girl Friend or BOY Friend Do you have Depression?  \
# ...

# %%
# Filling using mean
m = data['Calories'].mean()
data['Calories'].fillna(m,inplace=True)

# %%
# Shows display of all tows and columns
pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)
data
# Out:
#                Timestamp         gender   Age               emotion  \
# 0    05/07/2023 09:38:39           Male  21.0               Content
# 1    05/07/2023 09:38:57  Marabou stock  45.0                 Weird
# 2    05/07/2023 09:39:09        Female   20.0                 Happy
# 3    05/07/2023 09:39:12           Male  21.0                 Happy
# 4    05/07/2023 09:39:14         Female  21.0                 Happy
# 5                    NaN         Female  23.0                Happy
# 6    05/07/2023 09:39:21         female  21.0            irritated
# 7    05/07/2023 09:39:23        Female   22.0  In a state of wonder
# 8    05/07/2023 09:39:26           Male  22.0                   Sad
# 9    05/07/2023 09:39:27         Female  20.0                 happy
# 10            2023/12/26           Male  24.0                 Happy
# 11   05/07/2023 09:39:27         Female  20.0                 happy
# 12   05/07/2023 09:39:38           Male  25.0                 Happy
# ...

# %%
# Empty cells,wrong data,wrong formats duplicates
# Calculate median
med =data['Calories'].median()
data['Calories'].fillna(med,inplace=True)
data
# Out:
#                Timestamp         gender   Age               emotion  \
# 0    05/07/2023 09:38:39           Male  21.0               Content
# 1    05/07/2023 09:38:57  Marabou stock  45.0                 Weird
# 2    05/07/2023 09:39:09        Female   20.0                 Happy
# 3    05/07/2023 09:39:12           Male  21.0                 Happy
# 4    05/07/2023 09:39:14         Female  21.0                 Happy
# 5                    NaN         Female  23.0                Happy
# 6    05/07/2023 09:39:21         female  21.0            irritated
# 7    05/07/2023 09:39:23        Female   22.0  In a state of wonder
# 8    05/07/2023 09:39:26           Male  22.0                   Sad
# 9    05/07/2023 09:39:27         Female  20.0                 happy
# 10            2023/12/26           Male  24.0                 Happy
# 11   05/07/2023 09:39:27         Female  20.0                 happy
# 12   05/07/2023 09:39:38           Male  25.0                 Happy
# ...

# %%
#Exercise 1
#mode
mod =data['Age'].mode()
data['Age'].fillna(mod,inplace=True)
data
# Out:
#                Timestamp         gender   Age               emotion  \
# 0    05/07/2023 09:38:39           Male  21.0               Content
# 1    05/07/2023 09:38:57  Marabou stock  45.0                 Weird
# 2    05/07/2023 09:39:09        Female   20.0                 Happy
# 3    05/07/2023 09:39:12           Male  21.0                 Happy
# 4    05/07/2023 09:39:14         Female  21.0                 Happy
# 5                    NaN         Female  23.0                Happy
# 6    05/07/2023 09:39:21         female  21.0            irritated
# 7    05/07/2023 09:39:23        Female   22.0  In a state of wonder
# 8    05/07/2023 09:39:26           Male  22.0                   Sad
# 9    05/07/2023 09:39:27         Female  20.0                 happy
# 10            2023/12/26           Male  24.0                 Happy
# 11   05/07/2023 09:39:27         Female  20.0                 happy
# 12   05/07/2023 09:39:38           Male  25.0                 Happy
# ...

# %%
#wrong format rows that is hard to analyze(NAN,20230112 )
#NAN row 5 contained nan values and we filled with 
data['Timestamp'].fillna('05/07/2023 09:45:13', inplace=True)
data
# Out:
#                Timestamp         gender   Age               emotion  \
# 0    05/07/2023 09:38:39           Male  21.0               Content
# 1    05/07/2023 09:38:57  Marabou stock  45.0                 Weird
# 2    05/07/2023 09:39:09        Female   20.0                 Happy
# 3    05/07/2023 09:39:12           Male  21.0                 Happy
# 4    05/07/2023 09:39:14         Female  21.0                 Happy
# 5    05/07/2023 09:45:13         Female  23.0                Happy
# 6    05/07/2023 09:39:21         female  21.0            irritated
# 7    05/07/2023 09:39:23        Female   22.0  In a state of wonder
# 8    05/07/2023 09:39:26           Male  22.0                   Sad
# 9    05/07/2023 09:39:27         Female  20.0                 happy
# 10            2023/12/26           Male  24.0                 Happy
# 11   05/07/2023 09:39:27         Female  20.0                 happy
# 12   05/07/2023 09:39:38           Male  25.0                 Happy
# ...

# %%
#wrong data 
#age 21,2100

# %%
#Duplicates
#check if there are duplicates
print(data.duplicated())
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11      True
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
# 30     False
# 31     False
# 32     False
# 33     False
# 34     False
# 35     False
# 36     False
# 37     False
# 38     False
# 39     False
# 40     False
# 41     False
# 42     False
# 43     False
# 44     False
# 45     False
# 46     False
# 47     False
# 48     False
# 49     False
# 50     False
# 51     False
# 52     False
# 53     False
# 54     False
# 55     False
# 56     False
# 57     False
# 58     False
# 59     False
# 60     False
# 61     False
# 62     False
# 63     False
# 64     False
# 65     False
# ...

# %%
data.drop_duplicates(inplace=True)

# %%
print(data.duplicated())
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
# 30     False
# 31     False
# 32     False
# 33     False
# 34     False
# 35     False
# 36     False
# 37     False
# 38     False
# 39     False
# 40     False
# 41     False
# 42     False
# 43     False
# 44     False
# 45     False
# 46     False
# 47     False
# 48     False
# 49     False
# 50     False
# 51     False
# 52     False
# 53     False
# 54     False
# 55     False
# 56     False
# 57     False
# 58     False
# 59     False
# 60     False
# 61     False
# 62     False
# 63     False
# 64     False
# 65     False
# 66     False
# ...

# %%
# Data visualization,plotting,matplot lib library(Heatmap,piechart,barplot,lineplot(dotted,dashed))
#scatterplot library,histogram
data['Age'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>
