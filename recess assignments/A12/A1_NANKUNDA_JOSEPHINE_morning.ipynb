# %%
# Web Scrapping Assignment
from bs4 import BeautifulSoup
import requests
import csv
import json
url = "https://xeno-canto.org"

#Scrapping function
def extract_bird_species(url):
    response=requests.get(url)
    if response.status_code==200:
        soup=BeautifulSoup(response.content,'html.parser')
        species_list[]
        
        if bird_table:
            rows=bird_table.find_all('tr')
            for row in rows:
                columns row.find_all('td')
                for column in columns:
                    bird_link=column.find('a')
                    if bird_link:
                        species=bird_link.text.strip()
                        species_list.append(species)
        return species_list
    else:
        print(f"failed to fetch data from {url}.Status code:{response.status_code}")
        return[]
if_name_"_main_":
    url=""
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\urllib3\connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File ~\anaconda3\lib\site-packages\urllib3\util\connection.py:95, in create_connection(address, timeout, source_address, socket_options)
#      94 if err is not None:
# ---> 95     raise err
#      97 raise socket.error("getaddrinfo returns an empty list")
#
# File ~\anaconda3\lib\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84     sock.bind(source_address)
# ---> 85 sock.connect(sa)
#      86 return sock
#
# ...

# %%
# List of Bird Species with duplicates

if response.status_code == 200:
    try:
        data = response.json()
        if "recordings" in data:
            species_list = [recording["sp"] for recording in data["recordings"]]
            print(species_list)
    except JSONDecodeError as e:
        print("Error: Unable to parse JSON response from the API.")
else:
    print("Error: Unable to fetch data from the API.")

# %%
# Out:
#             <!doctype html>
#             <html>
#             <head>
#             <title>Results for 'grp:birds' :: page 1 :: xeno-canto</title>
#
#             <meta charset='utf-8'>
#             <meta name='robots' content='index,follow'>
#             <meta name='keywords' content='bird songs, bird sounds, grasshopper sounds, wildlife sounds, birds, grasshoppers, bird sound recordings, bird song recordings, bird song archive, bird sound archive, grasshopper sounds, xeno-canto'>
#
#             <link rel='icon' type='image/png' href='/static/img/favicon.png'>
#             <link rel='apple-touch-icon' type='image/png' href='/static/img/favicon-60.png'>
#             <link rel='apple-touch-icon' type='image/png' href='/static/img/favicon-76.png' sizes='76x76'>
#             <link rel='apple-touch-icon' type='image/png' href='/static/img/favicon-120.png' sizes='120x120'>
# ...

# %%
# Using the api query parameters(0).
result1 = requests.get("https://xeno-canto.org/api/2/recordings?query=troglodytes+troglodytes")

# Prints values from the API in json format
print(result1.json())
# Out:
# {'numRecordings': '4090', 'numSpecies': '1', 'page': 1, 'numPages': 9, 'recordings': [{'id': '819082', 'gen': 'Troglodytes', 'sp': 'troglodytes', 'ssp': '', 'group': 'birds', 'en': 'Eurasian Wren', 'rec': 'Uku Paal', 'cnt': 'Estonia', 'loc': 'Aiaste, Kanepi Parish, Põlva maakond', 'lat': '58.0479', 'lng': '26.6471', 'alt': '190', 'type': 'song', 'sex': '', 'stage': '', 'method': 'field recording', 'url': '//xeno-canto.org/819082', 'file': 'https://xeno-canto.org/819082/download', 'file-name': 'XC819082-TROTRO-AIASTE-230716_5418.mp3', 'sono': {'small': '//xeno-canto.org/sounds/uploaded/XIBLXHRPJO/ffts/XC819082-small.png', 'med': '//xeno-canto.org/sounds/uploaded/XIBLXHRPJO/ffts/XC819082-med.png', 'large': '//xeno-canto.org/sounds/uploaded/XIBLXHRPJO/ffts/XC819082-large.png', 'full': '//xeno-canto.org/sounds/uploaded/XIBLXHRPJO/ffts/XC819082-full.png'}, 'osci': {'small': '//xeno-canto.org/sounds/uploaded/XIBLXHRPJO/wave/XC819082-small.png', 'med': '//xeno-canto.org/sounds/uploaded/XIBL
# ...

# %%
# Using the api query parameters(1).
result1 = requests.get("https://xeno-canto.org/api/2/recordings?query=cnt:brazil")

# Prints values from the API in json format
print(result1.json())
# Out:
# {'numRecordings': '66117', 'numSpecies': '1671', 'page': 1, 'numPages': 133, 'recordings': [{'id': '754598', 'gen': 'Pyriglena', 'sp': 'similis', 'ssp': '', 'group': 'birds', 'en': 'Tapajos Fire-eye', 'rec': 'JAYRSON ARAUJO DE OLIVEIRA', 'cnt': 'Brazil', 'loc': 'Sinop, Cascalheiras - Mato Grosso', 'lat': '-11.7519', 'lng': '-55.638', 'alt': '340', 'type': 'song', 'sex': 'male', 'stage': 'adult', 'method': 'in the hand', 'url': '//xeno-canto.org/754598', 'file': 'https://xeno-canto.org/754598/download', 'file-name': 'XC754598-18-09-2022-8e21-Papa-taoca-do-tapajos.mp3', 'sono': {'small': '//xeno-canto.org/sounds/uploaded/LXKLWEDKEM/ffts/XC754598-small.png', 'med': '//xeno-canto.org/sounds/uploaded/LXKLWEDKEM/ffts/XC754598-med.png', 'large': '//xeno-canto.org/sounds/uploaded/LXKLWEDKEM/ffts/XC754598-large.png', 'full': '//xeno-canto.org/sounds/uploaded/LXKLWEDKEM/ffts/XC754598-full.png'}, 'osci': {'small': '//xeno-canto.org/sounds/uploaded/LXKLWEDKEM/wave/XC754598-small.png', 'med': '//
# ...

# %%
# Using the api query parameters(2).
result1 = requests.get("https://xeno-canto.org/api/2/recordings?query=bearded+bellbird+q:A")

# Prints values from the API in json format
print(result1.json())
# Out:
# {'numRecordings': '31', 'numSpecies': '1', 'page': 1, 'numPages': 1, 'recordings': [{'id': '769677', 'gen': 'Procnias', 'sp': 'averano', 'ssp': '', 'group': 'birds', 'en': 'Bearded Bellbird', 'rec': 'JAYRSON ARAUJO DE OLIVEIRA', 'cnt': 'Brazil', 'loc': 'Porto Franco, Maranhão Ecopousada Brasil', 'lat': '-6.3761', 'lng': '-47.1085', 'alt': '280', 'type': 'call, song', 'sex': 'uncertain', 'stage': 'adult', 'method': 'in the hand', 'url': '//xeno-canto.org/769677', 'file': 'https://xeno-canto.org/769677/download', 'file-name': 'XC769677-07-12-2022-9e49-Araponga-do-nordeste-PORTO-FRANCO.mp3', 'sono': {'small': '//xeno-canto.org/sounds/uploaded/LXKLWEDKEM/ffts/XC769677-small.png', 'med': '//xeno-canto.org/sounds/uploaded/LXKLWEDKEM/ffts/XC769677-med.png', 'large': '//xeno-canto.org/sounds/uploaded/LXKLWEDKEM/ffts/XC769677-large.png', 'full': '//xeno-canto.org/sounds/uploaded/LXKLWEDKEM/ffts/XC769677-full.png'}, 'osci': {'small': '//xeno-canto.org/sounds/uploaded/LXKLWEDKEM/wave/XC769677-s
# ...
